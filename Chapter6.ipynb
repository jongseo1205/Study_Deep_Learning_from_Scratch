# %%
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %%
class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
        
    def update(self, params, grads):
        if self.v is None:
            self.v = {}
            for key, val in params.items():
                self.v[key] = np.zeros_like(val)
                
        for key in params.keys():
            self.v[key] = self.momentum*self.v[key] - self.lr*grads[key]
            params[key] += self.v[key]

# %%
class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            for key, val in parms.items():
                self.h[key] = np.zeros_like(val)
                
        for key in parms.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100)
node_num = 100
hidden_layer_size = 5
activations = {}

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    w = np.random.randn(node_num, node_num) * 1
    a = np.dot(x, w)
    z = sigmoid(a)
    activations[i] = z

# %%
plt.rcParams['figure.figsize'] = 10, 6

# %%
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100)
node_num = 100
hidden_layer_size = 5
activations = {}

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    w = np.random.randn(node_num, node_num) * 0.01
    a = np.dot(x, w)
    z = sigmoid(a)
    activations[i] = z

# %%
w = np.random
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100)
node_num = 100
hidden_layer_size = 5
activations = {}

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    w = np.random.randn(node_num, node_num) / np.sqrt(node_num)
    a = np.dot(x, w)
    z = sigmoid(a)
    activations[i] = z

# %%
w = np.random
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
from dataset.mnist import load_mnist
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)
x_train = x_train[:300]
t_train = t_train[:300]

# %%
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD
network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)
optimizer = SGD(lr=0.01)
max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.12333333333333334, test acc:0.1103
# epoch:1, train acc:0.14333333333333334, test acc:0.1281
# epoch:2, train acc:0.18666666666666668, test acc:0.1508
# epoch:3, train acc:0.21666666666666667, test acc:0.1668
# epoch:4, train acc:0.24666666666666667, test acc:0.1881
# epoch:5, train acc:0.26666666666666666, test acc:0.2109
# epoch:6, train acc:0.29333333333333333, test acc:0.2163
# epoch:7, train acc:0.35, test acc:0.2348
# epoch:8, train acc:0.36666666666666664, test acc:0.2456
# epoch:9, train acc:0.38333333333333336, test acc:0.2544
# epoch:10, train acc:0.41, test acc:0.2804
# epoch:11, train acc:0.44666666666666666, test acc:0.3117
# epoch:12, train acc:0.47333333333333333, test acc:0.3196
# epoch:13, train acc:0.49666666666666665, test acc:0.3318
# epoch:14, train acc:0.5433333333333333, test acc:0.3682
# epoch:15, train acc:0.5533333333333333, test acc:0.3853
# epoch:16, train acc:0.5666666666666667, test acc:0.403
# epoch:17, train acc:0.63, test acc:0.4447
# epoch:18, train acc:0.64, test acc:0.4544
# epoch:19, train acc:0.6333333333333333, test acc:0.4587
# epoch:20, train acc:0.6833333333333333, test acc:0.4896
# epoch:21, train acc:0.6866666666666666, test acc:0.5069
# epoch:22, train acc:0.7166666666666667, test acc:0.5126
# epoch:23, train acc:0.7033333333333334, test acc:0.5235
# epoch:24, train acc:0.7666666666666667, test acc:0.555
# epoch:25, train acc:0.78, test acc:0.5584
# epoch:26, train acc:0.7533333333333333, test acc:0.5585
# epoch:27, train acc:0.7966666666666666, test acc:0.5778
# epoch:28, train acc:0.8066666666666666, test acc:0.5937
# epoch:29, train acc:0.8066666666666666, test acc:0.6013
# epoch:30, train acc:0.8366666666666667, test acc:0.6139
# epoch:31, train acc:0.8266666666666667, test acc:0.604
# epoch:32, train acc:0.83, test acc:0.6175
# epoch:33, train acc:0.83, test acc:0.6252
# epoch:34, train acc:0.82, test acc:0.6167
# epoch:35, train acc:0.85, test acc:0.6338
# epoch:36, train acc:0.85, test acc:0.6482
# epoch:37, train acc:0.8733333333333333, test acc:0.6552
# epoch:38, train acc:0.8666666666666667, test acc:0.648
# epoch:39, train acc:0.8766666666666667, test acc:0.6565
# epoch:40, train acc:0.87, test acc:0.6653
# epoch:41, train acc:0.89, test acc:0.676
# epoch:42, train acc:0.8833333333333333, test acc:0.673
# epoch:43, train acc:0.8833333333333333, test acc:0.6745
# epoch:44, train acc:0.89, test acc:0.6765
# epoch:45, train acc:0.89, test acc:0.6824
# epoch:46, train acc:0.8933333333333333, test acc:0.6888
# epoch:47, train acc:0.9033333333333333, test acc:0.6915
# epoch:48, train acc:0.9, test acc:0.6934
# epoch:49, train acc:0.91, test acc:0.6984
# epoch:50, train acc:0.9066666666666666, test acc:0.7031
# epoch:51, train acc:0.91, test acc:0.7086
# epoch:52, train acc:0.9133333333333333, test acc:0.7071
# epoch:53, train acc:0.9066666666666666, test acc:0.7021
# epoch:54, train acc:0.9133333333333333, test acc:0.7082
# epoch:55, train acc:0.9233333333333333, test acc:0.7053
# epoch:56, train acc:0.9233333333333333, test acc:0.7108
# epoch:57, train acc:0.93, test acc:0.713
# epoch:58, train acc:0.9366666666666666, test acc:0.7127
# epoch:59, train acc:0.9333333333333333, test acc:0.7098
# epoch:60, train acc:0.9433333333333334, test acc:0.7156
# epoch:61, train acc:0.9433333333333334, test acc:0.7209
# epoch:62, train acc:0.9466666666666667, test acc:0.7185
# epoch:63, train acc:0.95, test acc:0.7207
# epoch:64, train acc:0.9466666666666667, test acc:0.7288
# epoch:65, train acc:0.9566666666666667, test acc:0.7263
# epoch:66, train acc:0.9566666666666667, test acc:0.7304
# epoch:67, train acc:0.9566666666666667, test acc:0.7317
# epoch:68, train acc:0.9466666666666667, test acc:0.7242
# epoch:69, train acc:0.9633333333333334, test acc:0.7271
# epoch:70, train acc:0.9633333333333334, test acc:0.7375
# epoch:71, train acc:0.97, test acc:0.7374
# epoch:72, train acc:0.9566666666666667, test acc:0.7366
# epoch:73, train acc:0.96, test acc:0.7383
# epoch:74, train acc:0.9666666666666667, test acc:0.7399
# epoch:75, train acc:0.9766666666666667, test acc:0.7396
# epoch:76, train acc:0.98, test acc:0.7398
# epoch:77, train acc:0.98, test acc:0.7423
# epoch:78, train acc:0.9833333333333333, test acc:0.7426
# epoch:79, train acc:0.9866666666666667, test acc:0.7464
# epoch:80, train acc:0.9833333333333333, test acc:0.7423
# epoch:81, train acc:0.9833333333333333, test acc:0.7465
# epoch:82, train acc:0.9833333333333333, test acc:0.7396
# epoch:83, train acc:0.9833333333333333, test acc:0.7458
# epoch:84, train acc:0.99, test acc:0.742
# epoch:85, train acc:0.9866666666666667, test acc:0.7476
# epoch:86, train acc:0.9833333333333333, test acc:0.7449
# epoch:87, train acc:0.9833333333333333, test acc:0.7482
# epoch:88, train acc:0.9866666666666667, test acc:0.7505
# epoch:89, train acc:0.9866666666666667, test acc:0.751
# epoch:90, train acc:0.99, test acc:0.7506
# epoch:91, train acc:0.99, test acc:0.752
# epoch:92, train acc:0.9866666666666667, test acc:0.7499
# epoch:93, train acc:0.99, test acc:0.75
# epoch:94, train acc:0.99, test acc:0.7513
# epoch:95, train acc:0.99, test acc:0.7484
# epoch:96, train acc:0.99, test acc:0.7537
# epoch:97, train acc:0.9866666666666667, test acc:0.7506
# epoch:98, train acc:0.9933333333333333, test acc:0.7503
# epoch:99, train acc:0.9966666666666667, test acc:0.7518
# epoch:100, train acc:0.9933333333333333, test acc:0.7512
# epoch:101, train acc:0.9933333333333333, test acc:0.7528
# epoch:102, train acc:0.9933333333333333, test acc:0.7535
# epoch:103, train acc:0.9966666666666667, test acc:0.7541
# epoch:104, train acc:0.9933333333333333, test acc:0.7548
# epoch:105, train acc:0.9966666666666667, test acc:0.7535
# epoch:106, train acc:1.0, test acc:0.7543
# epoch:107, train acc:0.9966666666666667, test acc:0.7544
# epoch:108, train acc:1.0, test acc:0.7558
# epoch:109, train acc:1.0, test acc:0.7555
# epoch:110, train acc:1.0, test acc:0.7584
# epoch:111, train acc:1.0, test acc:0.7535
# epoch:112, train acc:1.0, test acc:0.7568
# epoch:113, train acc:1.0, test acc:0.7557
# epoch:114, train acc:1.0, test acc:0.7573
# epoch:115, train acc:1.0, test acc:0.755
# epoch:116, train acc:1.0, test acc:0.758
# epoch:117, train acc:1.0, test acc:0.7577
# epoch:118, train acc:1.0, test acc:0.7598
# epoch:119, train acc:1.0, test acc:0.7609
# epoch:120, train acc:1.0, test acc:0.7611
# epoch:121, train acc:1.0, test acc:0.7594
# epoch:122, train acc:1.0, test acc:0.7571
# epoch:123, train acc:1.0, test acc:0.7609
# epoch:124, train acc:1.0, test acc:0.7629
# epoch:125, train acc:1.0, test acc:0.7601
# epoch:126, train acc:1.0, test acc:0.7632
# epoch:127, train acc:1.0, test acc:0.7631
# epoch:128, train acc:1.0, test acc:0.7615
# epoch:129, train acc:1.0, test acc:0.7617
# epoch:130, train acc:1.0, test acc:0.7625
# epoch:131, train acc:1.0, test acc:0.7636
# epoch:132, train acc:1.0, test acc:0.7649
# epoch:133, train acc:1.0, test acc:0.7625
# epoch:134, train acc:1.0, test acc:0.7656
# epoch:135, train acc:1.0, test acc:0.7652
# epoch:136, train acc:1.0, test acc:0.7639
# epoch:137, train acc:1.0, test acc:0.7635
# epoch:138, train acc:1.0, test acc:0.7627
# epoch:139, train acc:1.0, test acc:0.7637
# epoch:140, train acc:1.0, test acc:0.7635
# epoch:141, train acc:1.0, test acc:0.7627
# epoch:142, train acc:1.0, test acc:0.763
# epoch:143, train acc:1.0, test acc:0.7649
# epoch:144, train acc:1.0, test acc:0.7659
# epoch:145, train acc:1.0, test acc:0.7658
# epoch:146, train acc:1.0, test acc:0.7659
# epoch:147, train acc:1.0, test acc:0.7658
# epoch:148, train acc:1.0, test acc:0.7667
# epoch:149, train acc:1.0, test acc:0.767
# epoch:150, train acc:1.0, test acc:0.7662
# epoch:151, train acc:1.0, test acc:0.7684
# epoch:152, train acc:1.0, test acc:0.766
# epoch:153, train acc:1.0, test acc:0.7661
# epoch:154, train acc:1.0, test acc:0.7654
# epoch:155, train acc:1.0, test acc:0.7663
# epoch:156, train acc:1.0, test acc:0.7658
# epoch:157, train acc:1.0, test acc:0.7682
# epoch:158, train acc:1.0, test acc:0.7672
# epoch:159, train acc:1.0, test acc:0.767
# epoch:160, train acc:1.0, test acc:0.7655
# epoch:161, train acc:1.0, test acc:0.765
# epoch:162, train acc:1.0, test acc:0.7667
# epoch:163, train acc:1.0, test acc:0.7681
# epoch:164, train acc:1.0, test acc:0.767
# epoch:165, train acc:1.0, test acc:0.7659
# epoch:166, train acc:1.0, test acc:0.7669
# epoch:167, train acc:1.0, test acc:0.7667
# epoch:168, train acc:1.0, test acc:0.7677
# epoch:169, train acc:1.0, test acc:0.7673
# epoch:170, train acc:1.0, test acc:0.7669
# epoch:171, train acc:1.0, test acc:0.768
# epoch:172, train acc:1.0, test acc:0.7667
# epoch:173, train acc:1.0, test acc:0.7663
# epoch:174, train acc:1.0, test acc:0.7662
# epoch:175, train acc:1.0, test acc:0.7669
# epoch:176, train acc:1.0, test acc:0.7676
# epoch:177, train acc:1.0, test acc:0.7651
# epoch:178, train acc:1.0, test acc:0.7667
# epoch:179, train acc:1.0, test acc:0.7667
# epoch:180, train acc:1.0, test acc:0.7662
# epoch:181, train acc:1.0, test acc:0.7666
# epoch:182, train acc:1.0, test acc:0.7674
# epoch:183, train acc:1.0, test acc:0.7687
# epoch:184, train acc:1.0, test acc:0.767
# epoch:185, train acc:1.0, test acc:0.7704
# epoch:186, train acc:1.0, test acc:0.77
# epoch:187, train acc:1.0, test acc:0.7705
# epoch:188, train acc:1.0, test acc:0.7693
# epoch:189, train acc:1.0, test acc:0.7687
# epoch:190, train acc:1.0, test acc:0.7682
# epoch:191, train acc:1.0, test acc:0.7702
# epoch:192, train acc:1.0, test acc:0.7693
# epoch:193, train acc:1.0, test acc:0.7699
# epoch:194, train acc:1.0, test acc:0.7716
# epoch:195, train acc:1.0, test acc:0.769
# epoch:196, train acc:1.0, test acc:0.7694
# epoch:197, train acc:1.0, test acc:0.7694
# epoch:198, train acc:1.0, test acc:0.77
# epoch:199, train acc:1.0, test acc:0.7703
# epoch:200, train acc:1.0, test acc:0.7701

# %%
class Dropout:
    def __init__(self, dropout_ratio = 0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None
    
    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x,shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)
        
    def backward(self, dout):
        return dout * self.mask

# %%
from common.util import shuffle_dataset

(x_train, t_train), (x_test, t_test) = load_mnist()

x_train, t_train = shuffle_dataset(x_train, t_train)
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)

x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

# %%
weight_decay = 10 ** np.random.uniform(-8, -4)
lr = 10 ** np.random.uniform(-6, -2)
